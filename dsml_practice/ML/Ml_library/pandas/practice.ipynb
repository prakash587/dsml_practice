# %% [markdown]
# ## columns name and data type

# %%
import pandas as pd

# %%
titanic_df= pd.read_csv("titanic-data.csv")

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## all passengers who survived.

# %%
titanic_df[titanic_df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## all passenger who are female and survived

# %%
titanic_df[(titanic_df['Sex']== 'female') & (titanic_df['Survived']== 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## all passengers who are male and in Pclass 1.

# %%
titanic_df[(titanic_df['Sex']=='male') &(titanic_df['Pclass']== 1)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
titanic_df[titanic_df['Age'] > 60].shape
# Out:
# (22, 12)

# %% [markdown]
# ## all passengers who paid more than 100 in Fare.

# %%
titanic_df[titanic_df['Fare']>100].shape
# Out:
# (53, 12)

# %% [markdown]
# ## passengers who embarked from 'S' and survived.

# %%
titanic_df[(titanic_df['Embarked']== 'S') & (titanic_df['Survived']==1)].shape
# Out:
# (217, 12)

# %% [markdown]
# ## vpassengers who were children (Age < 12)

# %%
titanic_df[titanic_df['Age']< 12].shape
# Out:
# (68, 12)

# %% [markdown]
# ## Filter rows where Age is missing.

# %%
titanic_df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# ## names and age of all passengers who paid exactly 0 fare.

# %%
titanic_df[titanic_df['Fare']==0].shape
# Out:
# (15, 12)

# %%
titanic_df[titanic_df['Fare']==0][['Name','Age']]
# Out:
#                                  Name   Age
# 179               Leonard, Mr. Lionel  36.0
# 263             Harrison, Mr. William  40.0
# 271      Tornquist, Mr. William Henry  25.0
# 277       Parkes, Mr. Francis "Frank"   NaN
# 302   Johnson, Mr. William Cahoone Jr  19.0
# 413    Cunningham, Mr. Alfred Fleming   NaN
# 466             Campbell, Mr. William   NaN
# 481  Frost, Mr. Anthony Wood "Archie"   NaN
# 597               Johnson, Mr. Alfred  49.0
# 633     Parr, Mr. William Henry Marsh   NaN
# 674        Watson, Mr. Ennis Hastings   NaN
# 732              Knight, Mr. Robert J   NaN
# 806            Andrews, Mr. Thomas Jr  39.0
# 815                  Fry, Mr. Richard   NaN
# 822   Reuchlin, Jonkheer. John George  38.0

# %% [markdown]
# ## all passengers with family aboard (SibSp + Parch >0

# %%
titanic_df[(titanic_df['SibSp'] + titanic_df['Parch']) > 0][['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# ..                                                 ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880       Shelley, Mrs. William (Imanita Parrish Hall)
# 885               Rice, Mrs. William (Margaret Norton)
# 888           Johnston, Miss. Catherine Helen "Carrie"
#
# [354 rows x 1 columns]

# %%
titanic_df['SibSp'] + titanic_df['Parch']>0
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Length: 891, dtype: bool
